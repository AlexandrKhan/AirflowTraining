# %% [markdown]
# # Create a new sqlalchemy Datasource
# Use this notebook to configure a new sqlalchemy Datasource and add it to your project.

# %%
import great_expectations as ge
from great_expectations.cli.datasource import sanitize_yaml_and_save_datasource, check_if_datasource_name_exists
context = ge.get_context()
# Out:
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\expectations\metrics\util.py:88: DeprecationWarning: The pybigquery package is obsolete and its usage within Great Expectations is deprecated as of v0.14.7. As support will be removed in v0.17, please transition to sqlalchemy-bigquery
#   DeprecationWarning,
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\expectations\core\expect_column_values_to_be_of_type.py:77: DeprecationWarning: The pybigquery package is obsolete and its usage within Great Expectations is deprecated as of v0.14.7. As support will be removed in v0.17, please transition to sqlalchemy-bigquery
#   DeprecationWarning,

# %% [markdown]
# ## Customize Your Datasource Configuration
#
# **If you are new to Great Expectations Datasources,** you should check out our [how-to documentation](https://docs.greatexpectations.io/docs/guides/connecting_to_your_data/connect_to_data_overview)
#
# **My configuration is not so simple - are there more advanced options?**
# Glad you asked! Datasources are versatile. Please see our [How To Guides](https://docs.greatexpectations.io/docs/guides/connecting_to_your_data/connect_to_data_overview)!
#
# Give your datasource a unique name:

# %%
datasource_name = "postgres_airflow"

# %% [markdown]
# ### For SQL based Datasources:
#
# Here we are creating an example configuration based on the database backend you specified in the CLI.  The configuration contains an **InferredAssetSqlDataConnector**, which will add a Data Asset for each table in the database, and a **RuntimeDataConnector** which can accept SQL queries. This is just an example, and you may customize this as you wish!
#
# Also, if you would like to learn more about the **DataConnectors** used in this configuration, please see our docs on [InferredAssetDataConnectors](https://docs.greatexpectations.io/docs/guides/connecting_to_your_data/how_to_configure_an_inferredassetdataconnector) and [RuntimeDataConnectors](https://docs.greatexpectations.io/docs/guides/connecting_to_your_data/how_to_configure_a_runtimedataconnector).
#
# Credentials will not be saved until you run the last cell. The credentials will be saved in `uncommitted/config_variables.yml` which should not be added to source control.

# %%
host = "localhost"
port = "5434"
username = "airflow"
password = "airflow"
database = "airflow"

# %%
example_yaml = f"""
name: {datasource_name}
class_name: Datasource
execution_engine:
  class_name: SqlAlchemyExecutionEngine
  credentials:
    host: {host}
    port: '{port}'
    username: {username}
    password: {password}
    database: {database}
    drivername: postgresql
data_connectors:
  default_runtime_data_connector_name:
    class_name: RuntimeDataConnector
    batch_identifiers:
      - default_identifier_name
  default_inferred_data_connector_name:
    class_name: InferredAssetSqlDataConnector
    include_schema_name: True"""
print(example_yaml)
# Out:
# name: postgres_airflow
# class_name: Datasource
# execution_engine:
#   class_name: SqlAlchemyExecutionEngine
#   credentials:
#     host: localhost
#     port: '5434'
#     username: airflow
#     password: airflow
#     database: airflow
#     drivername: postgresql
# data_connectors:
#   default_runtime_data_connector_name:
#     class_name: RuntimeDataConnector
#     batch_identifiers:
#       - default_identifier_name
#   default_inferred_data_connector_name:
#     class_name: InferredAssetSqlDataConnector
#     include_schema_name: True

# %% [markdown]
# # Test Your Datasource Configuration
# Here we will test your Datasource configuration to make sure it is valid.
#
# This `test_yaml_config()` function is meant to enable fast dev loops. **If your
# configuration is correct, this cell will show you some snippets of the data
# assets in the data source.** You can continually edit your Datasource config
# yaml and re-run the cell to check until the new config is valid.
#
# If you instead wish to use python instead of yaml to configure your Datasource,
# you can use `context.add_datasource()` and specify all the required parameters.

# %%
context.test_yaml_config(yaml_config=example_yaml)
# Out:
# Attempting to instantiate class from config...
# 	Instantiating as a Datasource, since class_name is Datasource
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# OperationalError: connection to server at "localhost" (::1), port 5434 failed: Connection refused (0x0000274D/10061)
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 5434 failed: Connection refused (0x0000274D/10061)
# 	Is the server running on that host and accepting TCP/IP connections?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\data_context\data_context\abstract_data_context.py in _instantiate_datasource_from_config(self, name, config)
#    1589             datasource: Datasource = self._build_datasource_from_config(
# -> 1590                 name=name, config=config
#    1591             )
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\data_context\data_context\abstract_data_context.py in _build_datasource_from_config(self, name, config)
#    1614             runtime_environment={"data_context": self, "concurrency": self.concurrency},
# -> 1615             config_defaults={"module_name": module_name},
#    1616         )
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\data_context\util.py in instantiate_class_from_config(config, runtime_environment, config_defaults)
#     116     try:
# --> 117         class_instance = class_(**config_with_defaults)
#     118     except TypeError as e:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\datasource\new_datasource.py in __init__(self, name, execution_engine, data_connectors, data_context_root_directory, concurrency, id_)
#     446         )
# --> 447         self._init_data_connectors(data_connector_configs=data_connectors)
#     448
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\datasource\new_datasource.py in _init_data_connectors(self, data_connector_configs)
#     455                 name=name,
# --> 456                 config=config,
#     457             )
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\datasource\new_datasource.py in _build_data_connector_from_config(self, name, config)
#     225             config_defaults={
# --> 226                 "module_name": "great_expectations.datasource.data_connector"
#     227             },
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\data_context\util.py in instantiate_class_from_config(config, runtime_environment, config_defaults)
#     116     try:
# --> 117         class_instance = class_(**config_with_defaults)
#     118     except TypeError as e:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\datasource\data_connector\inferred_asset_sql_data_connector.py in __init__(self, name, datasource_name, execution_engine, data_asset_name_prefix, data_asset_name_suffix, include_schema_name, splitter_method, splitter_kwargs, sampling_method, sampling_kwargs, excluded_tables, included_tables, skip_inapplicable_tables, introspection_directives, batch_spec_passthrough)
#      95             self._included_tables,
# ---> 96             self._skip_inapplicable_tables,
#      97         )
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\datasource\data_connector\inferred_asset_sql_data_connector.py in _refresh_introspected_assets_cache(self, data_asset_name_prefix, data_asset_name_suffix, include_schema_name, splitter_method, splitter_kwargs, sampling_method, sampling_kwargs, excluded_tables, included_tables, skip_inapplicable_tables)
#     132         introspected_table_metadata = self._introspect_db(
# --> 133             **self._introspection_directives
#     134         )
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\datasource\data_connector\inferred_asset_sql_data_connector.py in _introspect_db(self, schema_name, ignore_information_schemas_and_system_tables, information_schemas, system_tables, include_views)
#     211         engine = self._execution_engine.engine
# --> 212         inspector = sa.inspect(engine)
#     213
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\inspection.py in inspect(subject, raiseerr)
#      63                 return subject
# ---> 64             ret = reg(subject)
#      65             if ret is not None:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\reflection.py in _insp(bind)
#     138     def _insp(bind):
# --> 139         return Inspector.from_engine(bind)
#     140
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\reflection.py in from_engine(cls, bind)
#     133         if hasattr(bind.dialect, "inspector"):
# --> 134             return bind.dialect.inspector(bind)
#     135         return Inspector(bind)
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\dialects\postgresql\base.py in __init__(self, conn)
#    2447     def __init__(self, conn):
# -> 2448         reflection.Inspector.__init__(self, conn)
#    2449
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\reflection.py in __init__(self, bind)
#     107             # if engine, ensure initialized
# --> 108             bind.connect().close()
#     109
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\base.py in connect(self, **kwargs)
#    2262
# -> 2263         return self._connection_cls(self, **kwargs)
#    2264
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     103                 if connection is not None
# --> 104                 else engine.raw_connection()
#     105             )
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    2369         return self._wrap_pool_connect(
# -> 2370             self.pool.unique_connection, _connection
#    2371         )
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2339                 Connection._handle_dbapi_exception_noconnection(
# -> 2340                     e, dialect, self
#    2341                 )
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1583             util.raise_(
# -> 1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69                     exc_value,
# ---> 70                     with_traceback=exc_tb,
#      71                 )
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# OperationalError: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5434 failed: Connection refused (0x0000274D/10061)
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 5434 failed: Connection refused (0x0000274D/10061)
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# DatasourceInitializationError             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15056\759966091.py in <module>
# ----> 1 context.test_yaml_config(yaml_config=example_yaml)
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\data_context\data_context\base_data_context.py in test_yaml_config(self, yaml_config, name, class_name, runtime_environment, pretty_print, return_mode, shorten_tracebacks)
#    2519                 traceback.print_exc(limit=1)
#    2520             else:
# -> 2521                 raise e
#    2522
#    2523     def _test_yaml_config_prepare_config(
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\data_context\data_context\base_data_context.py in test_yaml_config(self, yaml_config, name, class_name, runtime_environment, pretty_print, return_mode, shorten_tracebacks)
#    2446                     usage_stats_event_payload,
#    2447                 ) = self._test_instantiation_of_datasource_from_yaml_config(
# -> 2448                     name, class_name, config
#    2449                 )
#    2450             elif class_name in self.TEST_YAML_CONFIG_SUPPORTED_CHECKPOINT_TYPES:
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\data_context\data_context\base_data_context.py in _test_instantiation_of_datasource_from_yaml_config(self, name, class_name, config)
#    2616                 config=config,
#    2617                 initialize=True,
# -> 2618                 save_changes=False,
#    2619             ),
#    2620         )
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\data_context\data_context\base_data_context.py in _instantiate_datasource_from_config_and_update_project_config(self, name, config, initialize, save_changes)
#    2871             config=config,
#    2872             initialize=initialize,
# -> 2873             save_changes=save_changes,
#    2874         )
#    2875         self._synchronize_self_with_underlying_data_context()
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\data_context\data_context\abstract_data_context.py in _instantiate_datasource_from_config_and_update_project_config(self, name, config, initialize, save_changes)
#    1661                 # If the DatasourceStore uses an InlineStoreBackend, the config may already be updated
#    1662                 self.config.datasources.pop(name, None)
# -> 1663                 raise e
#    1664
#    1665         return datasource
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\data_context\data_context\abstract_data_context.py in _instantiate_datasource_from_config_and_update_project_config(self, name, config, initialize, save_changes)
#    1652             try:
#    1653                 datasource: Datasource = self._instantiate_datasource_from_config(
# -> 1654                     name=name, config=substituted_config
#    1655                 )
#    1656                 self._cached_datasources[name] = datasource
#
# c:\users\aliaksandr_khan\appdata\local\programs\python\python37\lib\site-packages\great_expectations\data_context\data_context\abstract_data_context.py in _instantiate_datasource_from_config(self, name, config)
#    1592         except Exception as e:
#    1593             raise ge_exceptions.DatasourceInitializationError(
# -> 1594                 datasource_name=name, message=str(e)
#    1595             )
#    1596         return datasource
#
# DatasourceInitializationError: Cannot initialize datasource postgres_airflow, error: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5434 failed: Connection refused (0x0000274D/10061)
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 5434 failed: Connection refused (0x0000274D/10061)
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# ## Save Your Datasource Configuration
# Here we will save your Datasource in your Data Context once you are satisfied with the configuration. Note that `overwrite_existing` defaults to False, but you may change it to True if you wish to overwrite. Please note that if you wish to include comments you must add them directly to your `great_expectations.yml`.

# %%
sanitize_yaml_and_save_datasource(context, example_yaml, overwrite_existing=False)
context.list_datasources()

# %% [markdown]
# Now you can close this notebook and delete it!
